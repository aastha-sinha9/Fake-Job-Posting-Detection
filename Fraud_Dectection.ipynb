# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import tensorflow
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def load_data():
    df = pd.read_csv(r"C:\Users\aasth\Downloads\archive (1)\fake_job_postings.csv")
    return df

df = load_data()

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
df.info() ## A lot of null values are there
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
sns.countplot(x ='fraudulent',data=df)
plt.title("Class distribution of Fraudulent")
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
df = df.drop(['job_id', 'salary_range', 'telecommuting', 'has_company_logo', 
              'has_questions', 'benefits'], axis=1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17564 entries, 0 to 17879
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                17564 non-null  object
#  1   location             17223 non-null  object
#  2   department           6261 non-null   object
#  3   company_profile      14286 non-null  object
#  4   description          17563 non-null  object
#  5   requirements         14920 non-null  object
#  6   employment_type      14140 non-null  object
#  7   required_experience  10606 non-null  object
#  8   required_education   9559 non-null   object
#  9   industry             12731 non-null  object
#  10  function             11208 non-null  object
#  11  fraudulent           17564 non-null  int64
# dtypes: int64(1), object(11)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# title                      0
# location                 341
# department             11303
# company_profile         3278
# description                1
# requirements            2644
# employment_type         3424
# required_experience     6958
# required_education      8005
# industry                4833
# function                6356
# fraudulent                 0
# dtype: int64

# %%
df.dropna(subset=['description'],inplace=True)

# %%
text_columns = ['title','location','department','company_profile','description','requirements','industry']
for col in text_columns:
    df[col].fillna(' ',inplace=True)

# %%
df.head(1)
# Out:
#               title          location department  \
# 0  Marketing Intern  US, NY, New York  Marketing
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
#
#                                         requirements employment_type  \
# 0  Experience with content management systems a m...           Other
#
#   required_experience required_education industry   function  fraudulent
# 0          Internship                NaN           Marketing           0

# %%
df['Complete_description'] = df[text_columns].agg(' '.join, axis=1)

# %%
df.head(1)
# Out:
#               title          location department  \
# 0  Marketing Intern  US, NY, New York  Marketing
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
#
#                                         requirements employment_type  \
# 0  Experience with content management systems a m...           Other
#
#   required_experience required_education industry   function  fraudulent  \
# 0          Internship                NaN           Marketing           0
#
#                                 Complete_description
# 0  Marketing Intern US, NY, New York Marketing We...

# %%
import re
import pandas as pd
import nltk
from nltk.corpus import stopwords

# Download stopwords only once
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean_text_fast(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'<.*?>', '', text)         # Remove HTML tags
    text = re.sub(r'[^a-z\s]', ' ', text)     # Keep only letters and spaces
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return ' '.join(words)

# Apply on the correct column (change 'description' to your actual column name)
df['Complete_description_cleaned'] = df['Complete_description'].apply(clean_text_fast)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aasth\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.drop(['title','location','department','company_profile','requirements','description','industry','Complete_description'], axis = 1, inplace =True)

# %%
df.head()
# Out:
#   employment_type required_experience required_education  \
# 0           Other          Internship                NaN
# 1       Full-time      Not Applicable                NaN
# 2             NaN                 NaN                NaN
# 3       Full-time    Mid-Senior level  Bachelor's Degree
# 4       Full-time    Mid-Senior level  Bachelor's Degree
#
#                function  fraudulent  \
# 0             Marketing           0
# 1      Customer Service           0
# 2                   NaN           0
# 3                 Sales           0
# 4  Health Care Provider           0
#
#                         Complete_description_cleaned
# 0  marketing intern us ny new york marketing food...
# 1  customer service cloud video production nz auc...
# 2  commissioning machinery assistant cma us ia we...
# 3  account executive washington dc us dc washingt...
# 4  bill review manager us fl fort worth spotsourc...

# %%
print("Unique values in employement_type", df['employment_type'].unique())
print("Unique values in required_experience", df['required_experience'].unique())
print("Unique values in required_education",df['required_education'].unique())
print("Unique values in function",df['function'].unique())
# Out:
# Unique values in employement_type ['Other' 'Full-time' nan 'Part-time' 'Contract' 'Temporary']
# Unique values in required_experience ['Internship' 'Not Applicable' nan 'Mid-Senior level' 'Associate'
#  'Entry level' 'Executive' 'Director']
# Unique values in required_education [nan "Bachelor's Degree" "Master's Degree" 'High School or equivalent'
#  'Unspecified' 'Some College Coursework Completed' 'Vocational'
#  'Certification' 'Associate Degree' 'Professional' 'Doctorate'
#  'Some High School Coursework' 'Vocational - Degree'
#  'Vocational - HS Diploma']
# Unique values in function ['Marketing' 'Customer Service' nan 'Sales' 'Health Care Provider'
#  'Management' 'Information Technology' 'Other' 'Engineering'
#  'Administrative' 'Design' 'Production' 'Education' 'Supply Chain'
#  'Business Development' 'Product Management' 'Financial Analyst'
#  'Consulting' 'Human Resources' 'Project Management' 'Manufacturing'
#  'Public Relations' 'Strategy/Planning' 'Advertising' 'Finance'
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cat_cols = ['employment_type', 'required_experience', 'required_education', 'function']
df[cat_cols] = df[cat_cols].fillna("Unknown")


le = LabelEncoder()
df['employement_type_enc'] = le.fit_transform(df['employment_type'])
df['required_experience_enc'] = le.fit_transform(df['required_experience'])


for col in ['required_education','function']:
    freq_map = df[col].value_counts().to_dict()
    df[col + '_freq'] = df[col].map(freq_map)

df.drop(['employment_type','required_experience','required_education', 'function',], axis=1, inplace=True)

# %%
df.head()
# Out:
#    fraudulent                       Complete_description_cleaned  \
# 0           0  marketing intern us ny new york marketing food...
# 1           0  customer service cloud video production nz auc...
# 2           0  commissioning machinery assistant cma us ia we...
# 3           0  account executive washington dc us dc washingt...
# 4           0  bill review manager us fl fort worth spotsourc...
#
#    employement_type_enc  required_experience_enc  required_education_freq  \
# 0                     2                        4                     8004
# 1                     1                        6                     8004
# 2                     5                        7                     8004
# 3                     1                        5                     5089
# 4                     1                        5                     5089
#
#    function_freq
# 0            815
# 1           1170
# 2           6355
# 3           1444
# 4            324

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17563 entries, 0 to 17879
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fraudulent                    17563 non-null  int64
#  1   Complete_description_cleaned  17563 non-null  object
#  2   employement_type_enc          17563 non-null  int32
#  3   required_experience_enc       17563 non-null  int32
#  4   required_education_freq       17563 non-null  int64
#  5   function_freq                 17563 non-null  int64
# dtypes: int32(2), int64(3), object(1)
# memory usage: 823.3+ KB

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df['Complete_description_cleaned'])
sequences = tokenizer.texts_to_sequences(df['Complete_description_cleaned'])

X_seq = pad_sequences(sequences, maxlen=200)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout

# %%
y = df['fraudulent'].values
word_index = tokenizer.word_index
embedding_dim = 100
num_words = min(10000, len(word_index) + 1)

glove_path = r"C:\Users\aasth\Downloads\glove.6B\glove.6B.100d.txt"
embeddings_index = {}

with open(glove_path, encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = vector

print(f"Loaded {len(embeddings_index)} word vectors from GloVe.")



embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    if i >= num_words:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# Loaded 400001 word vectors from GloVe.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout

model = Sequential()
model.add(Embedding(input_dim=num_words,
                    output_dim=embedding_dim,
                    weights=[embedding_matrix],
                    input_length=200,
                    trainable=False))  # Freeze GloVe

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))  # Binary classification

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 200, 100)          1000000
#
#  flatten_1 (Flatten)         (None, 20000)             0
#
#  dense_2 (Dense)             (None, 128)               2560128
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# ...
# Total params: 3,560,257
# Trainable params: 2,560,257
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
from collections import Counter
print(Counter(y))
# Out:
# Counter({0: 16710, 1: 853})

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weight_dict = dict(enumerate(class_weights))

# %%
X = pad_sequences(sequences, maxlen=200)

model.fit(X, y, epochs=5, batch_size=32, validation_split=0.2, class_weight=class_weight_dict)
# Out:
# Epoch 1/5
# 440/440 [==============================] - 18s 37ms/step - loss: 0.7048 - accuracy: 0.7591 - val_loss: 0.1939 - val_accuracy: 0.9243
# Epoch 2/5
# 440/440 [==============================] - 15s 35ms/step - loss: 0.3632 - accuracy: 0.8815 - val_loss: 0.2451 - val_accuracy: 0.9342
# Epoch 3/5
# 440/440 [==============================] - 15s 34ms/step - loss: 0.2268 - accuracy: 0.9468 - val_loss: 0.2034 - val_accuracy: 0.9320
# Epoch 4/5
# 440/440 [==============================] - 14s 32ms/step - loss: 0.1940 - accuracy: 0.9497 - val_loss: 0.1602 - val_accuracy: 0.9451
# Epoch 5/5
# 440/440 [==============================] - 14s 33ms/step - loss: 0.1329 - accuracy: 0.9685 - val_loss: 0.2537 - val_accuracy: 0.9072

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = model.predict(X)
y_pred_binary = (y_pred > 0.5).astype(int)

print(classification_report(y, y_pred_binary))
# Out:
# 549/549 [==============================] - 3s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97     16710
#            1       0.48      0.83      0.61       853
#
#     accuracy                           0.95     17563
#    macro avg       0.74      0.89      0.79     17563
# weighted avg       0.97      0.95      0.95     17563

# %%
import pickle
with open("tokenizer.pkl", "wb") as file:
    pickle.dump(tokenizer, file)


model.save("ann_model.h5")
